# %%
import pandas as pd

# %%
import numpy as np

# %%
ls ./
# Out:
# 2020_dec_subset.csv      Unemployment.xls*        poverty.csv
# 2021_subset.csv          county_dict.csv          preprocess.ipynb
# Education.xls*           covid19Cases.csv*        unemployment.csv
# PopulationEstimates.xls* education.csv
# PovertyEstimates.xls*    population.csv

# %%
data = pd.read_excel('PopulationEstimates.xls')

# %%
data
# Out:
#       FIPStxt State                             Area_Name  \
# 0           0    US                         United States
# 1        1000    AL                               Alabama
# 2        1001    AL                        Autauga County
# 3        1003    AL                        Baldwin County
# 4        1005    AL                        Barbour County
# 5        1007    AL                           Bibb County
# 6        1009    AL                         Blount County
# 7        1011    AL                        Bullock County
# 8        1013    AL                         Butler County
# 9        1015    AL                        Calhoun County
# 10       1017    AL                       Chambers County
# 11       1019    AL                       Cherokee County
# 12       1021    AL                        Chilton County
# 13       1023    AL                        Choctaw County
# 14       1025    AL                         Clarke County
# ...

# %%
data.dropna(inplace=True)

# %%
data = pd.read_csv('2020_dec_subset.csv')

# %%
data
# Out:
#               date       county      state     fips  cases  deaths
# 0       2020-12-01      Autauga    Alabama   1001.0   2818    42.0
# 1       2020-12-01      Baldwin    Alabama   1003.0   9051   137.0
# 2       2020-12-01      Barbour    Alabama   1005.0   1189    11.0
# 3       2020-12-01         Bibb    Alabama   1007.0   1204    18.0
# 4       2020-12-01       Blount    Alabama   1009.0   3061    40.0
# 5       2020-12-01      Bullock    Alabama   1011.0    701    19.0
# 6       2020-12-01       Butler    Alabama   1013.0   1186    42.0
# 7       2020-12-01      Calhoun    Alabama   1015.0   6598   121.0
# 8       2020-12-01     Chambers    Alabama   1017.0   1827    50.0
# 9       2020-12-01     Cherokee    Alabama   1019.0   1051    24.0
# 10      2020-12-01      Chilton    Alabama   1021.0   2289    39.0
# 11      2020-12-01      Choctaw    Alabama   1023.0    431    14.0
# 12      2020-12-01       Clarke    Alabama   1025.0   1610    19.0
# ...

# %%
data.columns
# Out:
# Index(['FIPStxt', 'State', 'Area_Name', 'Rural-urban_Continuum Code_2003',
#        'Rural-urban_Continuum Code_2013', 'Urban_Influence_Code_2003',
#        'Urban_Influence_Code_2013', 'Economic_typology_2015',
#        'CENSUS_2010_POP', 'ESTIMATES_BASE_2010',
#        ...
#        'R_DOMESTIC_MIG_2019', 'R_NET_MIG_2011', 'R_NET_MIG_2012',
#        'R_NET_MIG_2013', 'R_NET_MIG_2014', 'R_NET_MIG_2015', 'R_NET_MIG_2016',
#        'R_NET_MIG_2017', 'R_NET_MIG_2018', 'R_NET_MIG_2019'],
#       dtype='object', length=165)

# %%
#my_dict = data.loc[:, ['fips', 'state', 'county']]
my_dict = data.loc[:, ['FIPStxt', 'State', 'Area_Name']]

# %%
my_dict.drop_duplicates().to_csv('county_dict.csv', index=0)

# %%
data = pd.read_csv('county_dict.csv')

# %%
data
# Out:
#       FIPStxt State           Area_Name
# 0        1001    AL      Autauga County
# 1        1003    AL      Baldwin County
# 2        1005    AL      Barbour County
# 3        1007    AL         Bibb County
# 4        1009    AL       Blount County
# 5        1011    AL      Bullock County
# 6        1013    AL       Butler County
# 7        1015    AL      Calhoun County
# 8        1017    AL     Chambers County
# 9        1019    AL     Cherokee County
# 10       1021    AL      Chilton County
# 11       1023    AL      Choctaw County
# 12       1025    AL       Clarke County
# 13       1027    AL         Clay County
# 14       1029    AL     Cleburne County
# 15       1031    AL       Coffee County
# 16       1033    AL      Colbert County
# 17       1035    AL      Conecuh County
# 18       1037    AL        Coosa County
# 19       1039    AL    Covington County
# 20       1041    AL     Crenshaw County
# 21       1043    AL      Cullman County
# ...

# %%
data = pd.read_excel('Education.xls')

# %%
data
# Out:
#       FIPS Code State                Area name  \
# 0             0    US            United States
# 1          1000    AL                  Alabama
# 2          1001    AL           Autauga County
# 3          1003    AL           Baldwin County
# 4          1005    AL           Barbour County
# 5          1007    AL              Bibb County
# 6          1009    AL            Blount County
# 7          1011    AL           Bullock County
# 8          1013    AL            Butler County
# 9          1015    AL           Calhoun County
# 10         1017    AL          Chambers County
# 11         1019    AL          Cherokee County
# 12         1021    AL           Chilton County
# 13         1023    AL           Choctaw County
# 14         1025    AL            Clarke County
# 15         1027    AL              Clay County
# 16         1029    AL          Cleburne County
# 17         1031    AL            Coffee County
# 18         1033    AL           Colbert County
# ...

# %%
data.columns
# Out:
# Index(['FIPS Code', 'State', 'Area name', '2003 Rural-urban Continuum Code',
#        '2003 Urban Influence Code', '2013 Rural-urban Continuum Code',
#        '2013 Urban Influence Code', 'Less than a high school diploma, 1970',
#        'High school diploma only, 1970', 'Some college (1-3 years), 1970',
#        'Four years of college or higher, 1970',
#        'Percent of adults with less than a high school diploma, 1970',
#        'Percent of adults with a high school diploma only, 1970',
#        'Percent of adults completing some college (1-3 years), 1970',
#        'Percent of adults completing four years of college or higher, 1970',
#        'Less than a high school diploma, 1980',
#        'High school diploma only, 1980', 'Some college (1-3 years), 1980',
#        'Four years of college or higher, 1980',
#        'Percent of adults with less than a high school diploma, 1980',
#        'Percent of adults with a high school diploma only, 1980',
# ...

# %%
data = data.dropna(subset=['2013 Rural-urban Continuum Code', '2013 Urban Influence Code'])

# %%
data
# Out:
#       FIPS Code State                Area name  \
# 2          1001    AL           Autauga County
# 3          1003    AL           Baldwin County
# 4          1005    AL           Barbour County
# 5          1007    AL              Bibb County
# 6          1009    AL            Blount County
# 7          1011    AL           Bullock County
# 8          1013    AL            Butler County
# 9          1015    AL           Calhoun County
# 10         1017    AL          Chambers County
# 11         1019    AL          Cherokee County
# 12         1021    AL           Chilton County
# 13         1023    AL           Choctaw County
# 14         1025    AL            Clarke County
# 15         1027    AL              Clay County
# 16         1029    AL          Cleburne County
# 17         1031    AL            Coffee County
# 18         1033    AL           Colbert County
# 19         1035    AL           Conecuh County
# 20         1037    AL             Coosa County
# ...

# %%
data = data.loc[:, ['FIPS Code', 'Percent of adults with less than a high school diploma, 2014-18', 'Percent of adults with a high school diploma only, 2014-18', "Percent of adults completing some college or associate's degree, 2014-18", "Percent of adults with a bachelor's degree or higher, 2014-18"]]

# %%
data.to_csv('education.csv', index=0)

# %%
data = pd.read_excel('PopulationEstimates.xls')

# %%
data.columns
# Out:
# Index(['FIPStxt', 'State', 'Area_Name', 'Rural-urban_Continuum Code_2003',
#        'Rural-urban_Continuum Code_2013', 'Urban_Influence_Code_2003',
#        'Urban_Influence_Code_2013', 'Economic_typology_2015',
#        'CENSUS_2010_POP', 'ESTIMATES_BASE_2010',
#        ...
#        'R_DOMESTIC_MIG_2019', 'R_NET_MIG_2011', 'R_NET_MIG_2012',
#        'R_NET_MIG_2013', 'R_NET_MIG_2014', 'R_NET_MIG_2015', 'R_NET_MIG_2016',
#        'R_NET_MIG_2017', 'R_NET_MIG_2018', 'R_NET_MIG_2019'],
#       dtype='object', length=165)

# %%
data = data.dropna(subset=['Rural-urban_Continuum Code_2013', 'Urban_Influence_Code_2013'])

# %%
data
# Out:
#       FIPStxt State                             Area_Name  \
# 2        1001    AL                        Autauga County
# 3        1003    AL                        Baldwin County
# 4        1005    AL                        Barbour County
# 5        1007    AL                           Bibb County
# 6        1009    AL                         Blount County
# 7        1011    AL                        Bullock County
# 8        1013    AL                         Butler County
# 9        1015    AL                        Calhoun County
# 10       1017    AL                       Chambers County
# 11       1019    AL                       Cherokee County
# 12       1021    AL                        Chilton County
# 13       1023    AL                        Choctaw County
# 14       1025    AL                         Clarke County
# 15       1027    AL                           Clay County
# 16       1029    AL                       Cleburne County
# ...

# %%
data = data.loc[:,['FIPStxt', 'POP_ESTIMATE_2019', 'Deaths_2019']]

# %%
data.to_csv('population.csv', index=None)

# %%
data = pd.read_excel('PovertyEstimates.xls')
data.columns
# Out:
# Index(['FIPStxt', 'Stabr', 'Area_name', 'Rural-urban_Continuum_Code_2003',
#        'Urban_Influence_Code_2003', 'Rural-urban_Continuum_Code_2013',
#        'Urban_Influence_Code_2013', 'POVALL_2019', 'CI90LBALL_2019',
#        'CI90UBALL_2019', 'PCTPOVALL_2019', 'CI90LBALLP_2019',
#        'CI90UBALLP_2019', 'POV017_2019', 'CI90LB017_2019', 'CI90UB017_2019',
#        'PCTPOV017_2019', 'CI90LB017P_2019', 'CI90UB017P_2019', 'POV517_2019',
#        'CI90LB517_2019', 'CI90UB517_2019', 'PCTPOV517_2019', 'CI90LB517P_2019',
#        'CI90UB517P_2019', 'MEDHHINC_2019', 'CI90LBINC_2019', 'CI90UBINC_2019',
#        'POV04_2019', 'CI90LB04_2019', 'CI90UB04_2019', 'PCTPOV04_2019',
#        'CI90LB04P_2019', 'CI90UB04P_2019'],
#       dtype='object')

# %%
data = data.dropna(subset=['Rural-urban_Continuum_Code_2013', 'Urban_Influence_Code_2013'])

# %%
data.loc[:, ['FIPStxt', 'POVALL_2019', 'PCTPOVALL_2019', 'MEDHHINC_2019']]
# Out:
#       FIPStxt  POVALL_2019  PCTPOVALL_2019  MEDHHINC_2019
# 2        1001         6723            12.1          58233
# 3        1003        22360            10.1          59871
# 4        1005         5909            27.1          35972
# 5        1007         4101            20.3          47918
# 6        1009         9324            16.3          52902
# 7        1011         2537            30.0          31906
# 8        1013         4124            21.6          39944
# 9        1015        18988            17.2          47747
# 10       1017         6415            19.6          42015
# 11       1019         4121            15.9          45982
# 12       1021         7044            16.0          49692
# 13       1023         2811            22.6          39808
# 14       1025         4281            18.4          43822
# 15       1027         2156            16.6          40562
# 16       1029         1945            13.3          51276
# ...

# %%
data.to_csv('poverty.csv', index=None)

# %%
data = pd.read_excel('Unemployment.xls')

# %%
data.columns
# Out:
# Index(['fips_txt', 'Stabr', 'area_name', 'Rural_urban_continuum_code_2013',
#        'Urban_influence_code_2013', 'Metro_2013', 'Civilian_labor_force_2000',
#        'Employed_2000', 'Unemployed_2000', 'Unemployment_rate_2000',
#        'Civilian_labor_force_2001', 'Employed_2001', 'Unemployed_2001',
#        'Unemployment_rate_2001', 'Civilian_labor_force_2002', 'Employed_2002',
#        'Unemployed_2002', 'Unemployment_rate_2002',
#        'Civilian_labor_force_2003', 'Employed_2003', 'Unemployed_2003',
#        'Unemployment_rate_2003', 'Civilian_labor_force_2004', 'Employed_2004',
#        'Unemployed_2004', 'Unemployment_rate_2004',
#        'Civilian_labor_force_2005', 'Employed_2005', 'Unemployed_2005',
#        'Unemployment_rate_2005', 'Civilian_labor_force_2006', 'Employed_2006',
#        'Unemployed_2006', 'Unemployment_rate_2006',
#        'Civilian_labor_force_2007', 'Employed_2007', 'Unemployed_2007',
# ...

# %%
data = data.dropna(subset=['Rural_urban_continuum_code_2013', 'Urban_influence_code_2013'])

# %%
data = data.loc[:,['flips_txt', 'Unemployed_2019', 'Unemployment_rate_2019']]

# %%
data.to_csv('unemployment.csv', index=None)

# %%
data = pd.read_csv('covid19Cases.csv')
data['date'] = pd.to_datetime(data['date'])
cutoff = pd.to_datetime('2020-12-01')
data[data['date']>=cutoff]
data = data.dropna(subset=['date', 'fips'])
print(data.shape)
data = data.drop_duplicates(['date','fips'], keep='last')
print(data.shape)
data['id'] = data.index
data[data['date']>=cutoff].to_csv('2020_dec_subset.csv', index=None)
# Out:
# (989140, 6)
# (989140, 6)

# %%
len(data.loc[:,['date', 'fips']].drop_duplicates())
# Out:
# 989140

# %%
data = pd.read_csv('2020_dec_subset.csv')

# %%
data.shape
# Out:
# (212379, 7)

# %%
data.loc[1062,:]
# Out:
# date      2020-12-01
# county       Madison
# state       Kentucky
# fips           21151
# cases           4024
# deaths            18
# Name: 1062, dtype: object

# %%
data.columns
# Out:
# Index(['date', 'county', 'state', 'fips', 'cases', 'deaths'], dtype='object')

# %%
data['date'].isnull().any()
# Out:
# False

# %%
data['fips'].isnull().any()
# Out:
# False

# %%
state_dict = pd.read_csv('county_dict.csv')

# %%
state_dict.columns
# Out:
# Index(['FIPStxt', 'State', 'Area_Name'], dtype='object')

# %%
covid_data = pd.read_csv('2020_dec_subset.csv')

# %%
covid_data.columns
# Out:
# Index(['date', 'county', 'state', 'fips', 'cases', 'deaths'], dtype='object')

# %%
covid_data['fips'].isin(state_dict['FIPStxt']).all()
# Out:
# False

# %%
pop_data = pd.read_csv('population.csv')

# %%
pop_data['FIPStxt'].isin(state_dict['FIPStxt']).all()
# Out:
# True

# %%
pop_data['FIPStxt'].isnull().any()
# Out:
# False

# %%
pov_data = pd.read_csv('poverty.csv')

# %%
pov_data['FIPStxt'].isin(state_dict['FIPStxt']).all()
# Out:
# True

# %%
pov_data['FIPStxt'].isnull().any()
# Out:
# False

# %%
ed_data = pd.read_csv('education.csv')
ed_data['FIPS Code'].isin(state_dict['FIPStxt']).all()
# Out:
# True

# %%
ed_data['FIPS Code'].isnull().any()
# Out:
# False

# %%
ed_data.columns
# Out:
# Index(['FIPS Code',
#        'Percent of adults with less than a high school diploma, 2014-18',
#        'Percent of adults with a high school diploma only, 2014-18',
#        'Percent of adults completing some college or associate's degree, 2014-18',
#        'Percent of adults with a bachelor's degree or higher, 2014-18'],
#       dtype='object')

# %%
sum(ed_data['FIPS Code'].isin(state_dict['FIPStxt']))
# Out:
# 3221

# %%
em_data = pd.read_csv('unemployment.csv')

# %%
em_data['fips_txt'].isin(state_dict['FIPStxt']).all()
# Out:
# True

# %%
em_data['fips_txt'].isnull().any()
# Out:
# False

# %%
covid_data.loc[:,['fips', 'state', 'county']]
# Out:
#            fips      state       county
# 0        1001.0    Alabama      Autauga
# 1        1003.0    Alabama      Baldwin
# 2        1005.0    Alabama      Barbour
# 3        1007.0    Alabama         Bibb
# 4        1009.0    Alabama       Blount
# 5        1011.0    Alabama      Bullock
# 6        1013.0    Alabama       Butler
# 7        1015.0    Alabama      Calhoun
# 8        1017.0    Alabama     Chambers
# 9        1019.0    Alabama     Cherokee
# 10       1021.0    Alabama      Chilton
# 11       1023.0    Alabama      Choctaw
# 12       1025.0    Alabama       Clarke
# 13       1027.0    Alabama         Clay
# 14       1029.0    Alabama     Cleburne
# 15       1031.0    Alabama       Coffee
# 16       1033.0    Alabama      Colbert
# 17       1035.0    Alabama      Conecuh
# 18       1037.0    Alabama        Coosa
# 19       1039.0    Alabama    Covington
# 20       1041.0    Alabama     Crenshaw
# 21       1043.0    Alabama      Cullman
# ...

# %%
mask = list(~pop_data_or['FIPStxt'].isin(state_dict['FIPStxt']))
state_dict = state_dict.append(pop_data_or.loc[mask,:])
#state_dict.append(pop_data_or[mask,:])

# %%
state_dict = state_dict.append(pop_data_or.loc[mask,:])
# Out:
#       FIPStxt State                             Area_Name
# 0        1001    AL                        Autauga County
# 1        1003    AL                        Baldwin County
# 2        1005    AL                        Barbour County
# 3        1007    AL                           Bibb County
# 4        1009    AL                         Blount County
# 5        1011    AL                        Bullock County
# 6        1013    AL                         Butler County
# 7        1015    AL                        Calhoun County
# 8        1017    AL                       Chambers County
# 9        1019    AL                       Cherokee County
# 10       1021    AL                        Chilton County
# 11       1023    AL                        Choctaw County
# 12       1025    AL                         Clarke County
# 13       1027    AL                           Clay County
# 14       1029    AL                       Cleburne County
# ...

# %%
pwd
# Out:
# '/Users/chloewang/Downloads/cis_550_project/data'
